# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def load(pth:str):
    df = pd.read_csv(pth)
    return df.drop(axis=1, columns="Unnamed: 0")
df_kirc, df_lusc = load("kirc_final_form.csv"), load("lusc_final_form.csv")

# %%
df_kirc.head(5)
# Out:
#    FBXO22  AURKC   AKAP7  CCDC158  ZBTB39  CNV_Xq11.2   CNV_17q24.3  \
# 0  450.94  10.55  205.50    13.42   70.01     0.002220    -0.006229
# 1  642.59  13.72  199.85     2.43   50.63    -0.024114    -0.015604
# 2  698.41  41.52  140.04     4.17   30.78    -0.009681     0.010842
# 3  808.00   9.56  283.05     9.27   43.94    -0.063156    -0.020687
# 4  511.00  21.78  295.11    43.63   28.24    -0.064738     0.014692
#
#    CNV_7q36.3   CNV_3p21.32   CNV_14q31.1   ...  CNV_5q35.1   CNV_1p36.23   \
# 0     0.001387      0.003125      0.001942  ...     0.440710      0.000000
# 1     0.001387     -0.403740      0.135090  ...     0.014190     -0.010892
# 2     0.095508     -0.082060     -0.000416  ...     0.115940     -0.115250
# 3     0.989080     -0.530730      0.000000  ...    -0.011611     -0.023840
# 4     0.607200     -0.639790      0.015620  ...    -0.002078     -0.629790
#
#    CNV_1p31.1    CNV_10p14    CNV_4q32.1   CNV_10q23.31  CNV_9p23      \
# 0      0.000000    -0.001940    -0.451790      0.002775     -0.001247
# 1     -0.010892    -0.007886     0.007222     -0.007886     -0.001524
# 2      0.019028    -0.063435     0.000000     -0.063435     -0.070536
# 3      0.004481    -0.001801     0.003885     -0.001801      0.006692
# 4     -0.629790    -0.009819    -0.005434     -0.643580      0.000000
#
#    CNV_3p12.2    CNV_3q11.2    CNV_Xp11.4
# 0      0.006526      0.008165     0.002220
# 1     -0.406390      0.002636    -0.024114
# 2     -0.082060     -0.082060    -0.009681
# 3     -0.507840      0.005136    -0.063156
# 4     -0.638690     -0.638690    -0.064738
#
# [5 rows x 35 columns]

# %%
df_lusc.head(5)
# Out:
#       DES    FMO5    HMCES    NEXN   SLC7A5  CNV_6q12      CNV_18q11.2   \
# 0  231.32   77.79  1572.76  159.90  1551.09       1.94270      0.078871
# 1   81.14  199.85  2287.20   42.41  1745.20       3.65690     -0.132640
# 2   27.64   12.55  1340.84   88.26  1561.89       0.12739      3.656900
# 3  293.07   19.82  1605.83  165.57  4639.29       0.37940     -0.004569
# 4   95.34   22.10  1388.16   70.51  2271.40       0.42099      0.211150
#
#    CNV_12p  CNV_4q22.1    CNV_13q34     ...  CNV_19q13.2   CNV_7q21.2    \
# 0    0.000      -0.10211      0.060508  ...       0.14280       0.16661
# 1    2.770      -0.44681     -0.595650  ...       1.24590       0.44577
# 2    1.158      -0.25353     -0.313810  ...       0.61785       0.33267
# 3    0.661      -0.38649     -0.399190  ...       0.80383       0.36395
# 4    0.000      -0.47099     -0.534700  ...       0.35594       0.61697
#
#    CNV_1q21.2    CNV_3p12.1    CNV_3p11.1    CNV_17p11.2   CNV_13q14.2   \
# 0      0.033127      -0.12393      -0.13331      0.076422     -0.048229
# 1      0.845930      -0.41970      -0.41970      1.208900      0.604870
# 2      0.861920      -0.25245       0.13344     -0.001825     -0.133570
# 3      0.451510      -0.39830      -0.39830     -0.048372     -0.399920
# 4      0.354630      -0.61964      -1.29290     -0.512080     -0.534800
#
#    CNV_2q22.1    CNV_4p  CNV_4q
# 0      0.000000  -0.102  -0.102
# 1      0.112470  -0.447  -0.447
# 2     -0.043354  -0.160  -0.160
# 3      0.026930  -0.386  -0.386
# 4      0.327430  -0.471  -0.471
#
# [5 rows x 107 columns]

# %%
df_lusc.columns
# Out:
# Index(['DES', 'FMO5', 'HMCES', 'NEXN', 'SLC7A5', 'CNV_6q12    ',
#        'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ', 'CNV_13q34   ',
#        ...
#        'CNV_19q13.2 ', 'CNV_7q21.2  ', 'CNV_1q21.2  ', 'CNV_3p12.1  ',
#        'CNV_3p11.1  ', 'CNV_17p11.2 ', 'CNV_13q14.2 ', 'CNV_2q22.1  ',
#        'CNV_4p', 'CNV_4q'],
#       dtype='object', length=107)

# %%
def to_x_y(df):
    cols = df.columns
    targets = df.loc[:,cols[:5]]
    features = df.loc[:,cols[5:]]
    return features, targets
kirc_data, lusc_data = to_x_y(df_kirc), to_x_y(df_lusc)

# %%
def train_models(data, model_name):
    features, targets = data
    features = StandardScaler().fit_transform(features)
    model_results = {}
    models = {}
    
    for target_name, target in targets.items():
        if model_name == "Ridge":
            # Define the parameter grid for Ridge
            param_grid = {
                'alpha': np.logspace(-2, 2, 100)  
            }
            ridge_model = Ridge( max_iter=10000)  
            randomized_search = RandomizedSearchCV(ridge_model, param_distributions=param_grid, n_iter=10, cv=5, scoring='r2', random_state=42)
            randomized_search.fit(features, target)  # Perform randomized search
            best_ridge_model = randomized_search.best_estimator_
            models["ridge_model_" + target_name] = best_ridge_model
            y_pred = best_ridge_model.predict(features)
            r2 = r2_score(target, y_pred)
            mse = mean_squared_error(target, y_pred)
            model_results["ridge_model_" + target_name] = {("r2","mse"): [r2,mse]}
        
        elif model_name == "Lasso":
            # Define the parameter grid for Lasso
            param_grid = {
                'alpha': np.logspace(-2, 2, 100)  # Creates a range of alpha values from 0.01 to 100
            }
            lasso_model = Lasso( max_iter=10000)  # Create a Lasso model
            randomized_search = RandomizedSearchCV(lasso_model, param_distributions=param_grid, n_iter=10, cv=5, scoring='r2', random_state=42)
            randomized_search.fit(features, target)  # Perform randomized search
            best_lasso_model = randomized_search.best_estimator_
            models["lasso_model_" + target_name] = best_lasso_model
            y_pred = best_lasso_model.predict(features)
            r2 = r2_score(target, y_pred)
            mse = mean_squared_error(target, y_pred)

            model_results["lasso_model_" + target_name] = {("r2","mse"): [r2,mse]}
        
        else:
            raise ValueError("Use 'Ridge' or 'Lasso' for model_name")
    
    return models, model_results

kirc_ridge_models, kirc_ridge_results = train_models(kirc_data, "Ridge")
kirc_lasso_models, kirc_lasso_results = train_models(kirc_data, "Lasso")
# Out:
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.175e+03, tolerance: 1.091e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.104e+03, tolerance: 1.091e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.927e+02, tolerance: 1.267e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.545e+04, tolerance: 1.091e+02
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.417e+02, tolerance: 2.829e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.302e+03, tolerance: 2.637e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.048e+02, tolerance: 2.829e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.593e+04, tolerance: 2.637e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.611e+03, tolerance: 2.829e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.499e+04, tolerance: 2.637e+01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.541e+00, tolerance: 2.422e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.637e+01, tolerance: 2.422e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.111e+00, tolerance: 2.709e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.324e+00, tolerance: 3.012e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.175e+00, tolerance: 1.100e+00
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\EGYPT\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.175e+01, tolerance: 1.436e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
print(kirc_ridge_results)
print(kirc_lasso_results)
# Out:
# {'ridge_model_FBXO22': {('r2', 'mse'): [0.5278038541744479, 12108.118331040767]}, 'ridge_model_AURKC': {('r2', 'mse'): [0.3081628865439239, 60.31244577978992]}, 'ridge_model_AKAP7': {('r2', 'mse'): [0.3853871062078382, 3434.1929408189967]}, 'ridge_model_CCDC158': {('r2', 'mse'): [0.37601873648677553, 338.5599156077676]}, 'ridge_model_ZBTB39': {('r2', 'mse'): [0.49515469345104546, 146.0014927566762]}}
# {'lasso_model_FBXO22': {('r2', 'mse'): [0.2925143068506658, 18141.44517252217]}, 'lasso_model_AURKC': {('r2', 'mse'): [0.0, 87.17723378339558]}, 'lasso_model_AKAP7': {('r2', 'mse'): [0.10471155613310323, 5002.487394877579]}, 'lasso_model_CCDC158': {('r2', 'mse'): [0.0, 542.5802590634876]}, 'lasso_model_ZBTB39': {('r2', 'mse'): [0.0, 289.2004557885665]}}

# %%
lusc_ridge_models, lusc_ridge_results = train_models(lusc_data, "Ridge")
lusc_lasso_models, lusc_lasso_results = train_models(lusc_data, "Lasso")

# %%
print(lusc_ridge_results)
print(lusc_lasso_results)
# Out:
# {'ridge_model_DES': {('r2', 'mse'): [0.9999992093904378, 0.006586707294205562]}, 'ridge_model_FMO5': {('r2', 'mse'): [0.9248989791381171, 307.8646042841314]}, 'ridge_model_HMCES': {('r2', 'mse'): [0.9654634919721381, 10174.446298554061]}, 'ridge_model_NEXN': {('r2', 'mse'): [0.9988059709837754, 4.014956796828832]}, 'ridge_model_SLC7A5': {('r2', 'mse'): [0.9398826561063115, 77847.08303096736]}}
# {'lasso_model_DES': {('r2', 'mse'): [0.5954810209272261, 3370.1187511129515]}, 'lasso_model_FMO5': {('r2', 'mse'): [0.9135209258064937, 354.50711122030367]}, 'lasso_model_HMCES': {('r2', 'mse'): [0.9999999918551148, 0.0023994810562466685]}, 'lasso_model_NEXN': {('r2', 'mse'): [0.9999974407625158, 0.008605509407394712]}, 'lasso_model_SLC7A5': {('r2', 'mse'): [0.9999999268929504, 0.094667698173142]}}

# %%
print(kirc_lasso_results)
print(kirc_ridge_results)
# Out:
# {'lasso_model_FBXO22': {('r2', 'mse'): [0.2925143068506658, 18141.44517252217]}, 'lasso_model_AURKC': {('r2', 'mse'): [0.0, 87.17723378339558]}, 'lasso_model_AKAP7': {('r2', 'mse'): [0.10471155613310323, 5002.487394877579]}, 'lasso_model_CCDC158': {('r2', 'mse'): [0.0, 542.5802590634876]}, 'lasso_model_ZBTB39': {('r2', 'mse'): [0.0, 289.2004557885665]}}
# {'ridge_model_FBXO22': {('r2', 'mse'): [0.5278038541744479, 12108.118331040767]}, 'ridge_model_AURKC': {('r2', 'mse'): [0.3081628865439239, 60.31244577978992]}, 'ridge_model_AKAP7': {('r2', 'mse'): [0.3853871062078382, 3434.1929408189967]}, 'ridge_model_CCDC158': {('r2', 'mse'): [0.37601873648677553, 338.5599156077676]}, 'ridge_model_ZBTB39': {('r2', 'mse'): [0.49515469345104546, 146.0014927566762]}}

# %%
def features_selection(features, models_dict):
    lasso_selection_results = {}
    
    for name, model in models_dict.items():
        non_zero_indices = np.where(model.coef_ != 0)
        selected_feature_names = features[non_zero_indices]
        selected_coefficients = model.coef_[non_zero_indices]
        lasso_selection_results[name] = {
            'selected_features': selected_feature_names,
            'coefficients': selected_coefficients
        }
    
    return lasso_selection_results
lusc_lasso_fs = features_selection(lusc_data[0].columns, lusc_lasso_models)
kirc_lasso_fs = features_selection(kirc_data[0].columns, kirc_lasso_models)
lusc_ridge_fs = features_selection(lusc_data[0].columns, lusc_ridge_models)
kirc_ridge_fs = features_selection(kirc_data[0].columns, kirc_ridge_models)

# %%
kirc = {
        ("results_ridge","results_lasso") : (kirc_ridge_results, kirc_lasso_results),
        ("models_ridge","models_lasso") : (kirc_ridge_models, kirc_lasso_models),
        ("selected_features_ridge", "selected_features_lasso") : (kirc_ridge_fs, kirc_lasso_fs)
         }

lusc = {        
        ("results_ridge","results_lasso") : (lusc_ridge_results, lusc_lasso_results),
        ("models_ridge","models_lasso") : (lusc_ridge_models, lusc_lasso_models),
        ("selected_features_ridge", "selected_features_lasso") : (lusc_ridge_fs, lusc_lasso_fs)
         }

final = {"kirc":kirc, "lusc":lusc}

# %%
final
# Out:
# {'kirc': {('results_ridge',
#    'results_lasso'): ({'ridge_model_FBXO22': {('r2',
#       'mse'): [0.5278038541744479, 12108.118331040767]},
#     'ridge_model_AURKC': {('r2', 'mse'): [0.3081628865439239,
#       60.31244577978992]},
#     'ridge_model_AKAP7': {('r2', 'mse'): [0.3853871062078382,
#       3434.1929408189967]},
#     'ridge_model_CCDC158': {('r2', 'mse'): [0.37601873648677553,
#       338.5599156077676]},
#     'ridge_model_ZBTB39': {('r2', 'mse'): [0.49515469345104546,
#       146.0014927566762]}}, {'lasso_model_FBXO22': {('r2',
#       'mse'): [0.2925143068506658, 18141.44517252217]},
#     'lasso_model_AURKC': {('r2', 'mse'): [0.0, 87.17723378339558]},
#     'lasso_model_AKAP7': {('r2', 'mse'): [0.10471155613310323,
#       5002.487394877579]},
#     'lasso_model_CCDC158': {('r2', 'mse'): [0.0, 542.5802590634876]},
#     'lasso_model_ZBTB39': {('r2', 'mse'): [0.0, 289.2004557885665]}}),
#   ('models_ridge',
#    'models_lasso'): ({'ridge_model_FBXO22': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_AURKC': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_AKAP7': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_CCDC158': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_ZBTB39': Ridge(alpha=22.570197196339215, max_iter=10000)}, {'lasso_model_FBXO22': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_AURKC': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_AKAP7': Lasso(alpha=17.07352647470692, max_iter=10000),
#     'lasso_model_CCDC158': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_ZBTB39': Lasso(alpha=22.570197196339215, max_iter=10000)}),
#   ('selected_features_ridge',
#    'selected_features_lasso'): ({'ridge_model_FBXO22': {'selected_features': Index(['CNV_Xq11.2 ', 'CNV_17q24.3', 'CNV_7q36.3 ', 'CNV_3p21.32 ',
#             'CNV_14q31.1 ', 'CNV_3q26.32', 'CNV_8p23.2  ', 'CNV_3p', 'CNV_1q43    ',
#             'CNV_Xq23    ', 'CNV_4q34.3  ', 'CNV_8q24.22', 'CNV_1q24.1 ',
#             'CNV_2q37.3  ', 'CNV_9p21.3  ', 'CNV_13q13.3 ', 'CNV_6q26    ',
#             'CNV_Xp22.2 ', 'CNV_1q32.1 ', 'CNV_3p25.3  ', 'CNV_5q35.1 ',
#             'CNV_1p36.23 ', 'CNV_1p31.1  ', 'CNV_10p14  ', 'CNV_4q32.1 ',
#             'CNV_10q23.31', 'CNV_9p23    ', 'CNV_3p12.2  ', 'CNV_3q11.2  ',
#             'CNV_Xp11.4 '],
#            dtype='object'),
#      'coefficients': array
#     'lasso_model_AKAP7': {'selected_features': Index(['CNV_3p', 'CNV_6q26    '], dtype='object'),
#      'coefficients': array([-5.66953075,  8.51073461])},
#     'lasso_model_CCDC158': {'selected_features': Index([], dtype='object'),
#      'coefficients': array([], dtype=float64)},
#     'lasso_model_ZBTB39': {'selected_features': Index([], dtype='object'),
#      'coefficients': array([], dtype=float64)}})},
#  'lusc': {('results_ridge',
#    'results_lasso'): ({'ridge_model_DES': {('r2', 'mse'): [0.9999992093904378,
#       0.006586707294205562]},
#     'ridge_model_FMO5': {('r2', 'mse'): [0.9248989791381171,
#       307.8646042841314]},
#     'ridge_model_HMCES': {('r2', 'mse'): [0.9654634919721381,
#       10174.446298554061]},
#     'ridge_model_NEXN': {('r2', 'mse'): [0.9988059709837754,
#       4.014956796828832]},
#     'ridge_model_SLC7A5': {('r2', 'mse'): [0.9398826561063115,
#       77847.08303096736]}}, {'lasso_model_DES': {('r2',
#       'mse'): [0.5954810209272261, 3370.1187511129515]},
#     'lasso_model_FMO5': {('r2', 'mse'): [0.9135209258064937,
#       354.50711122030367]},
#     'lasso_model_HMCES': {('r2', 'mse'): [0.9999999918551148,
#       0.0023994810562466685]},
#     'lasso_model_NEXN': {('r2', 'mse'): [0.9999974407625158,
#       0.008605509407394712]},
#     'lasso_model_SLC7A5': {('r2', 'mse'): [0.9999999268929504,
#       0.094667698173142]}}),
#   ('models_ridge',
#    'models_lasso'): ({'ridge_model_DES': Ridge(alpha=0.01, max_iter=10000),
#     'ridge_model_FMO5': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_HMCES': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_NEXN': Ridge(alpha=1.384886371393873, max_iter=10000),
#     'ridge_model_SLC7A5': Ridge(alpha=22.570197196339215, max_iter=10000)}, {'lasso_model_DES': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_FMO5': Lasso(alpha=6.7341506577508286, max_iter=10000),
#     'lasso_model_HMCES': Lasso(alpha=0.01, max_iter=10000),
#     'lasso_model_NEXN': Lasso(alpha=0.025353644939701114, max_iter=10000),
#     'lasso_model_SLC7A5': Lasso(alpha=0.0774263682681127, max_iter=10000)}),
#   ('selected_features_ridge',
#    'selected_features_lasso'): ({'ridge_model_DES': {'selected_features': Index(['CNV_6q12    ', 'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ',
#             'CNV_13q34   ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_5q', 'CNV_5p',
#             'CNV_3p25.3  ',
#             ...
#             'CNV_19q13.2 ', 'CNV_7q21.2  ', 'CNV_1q21.2  ', 'CNV_3p12.1  ',
#             'CNV_3p11.1  ', 'CNV_17p11.2 ', 'CNV_13q14.2 ', 'CNV_2q22.1  ',
#             'CNV_4p', 'CNV_4q'],
#            dtype='object', length=102),
#      'coefficients': array([ 31.48060036,  -1.20979486,  -7.84925279,  -7.69775213,
#               8.86496014,   4.0498432 ,  -1.20291803, -12.11557966,
#              -8.81219931, -10.49312872,  -9.8984265 ,  -9.89230922,
#               8.48355062,   0.04341117,   1.9480441 , -11.48609287,
#               2.76150947,   7.24366523,   8.56454878,  -2.08132097,
#               1.32148698,  -0.80179343,   3.49382142,   1.35962967,
#              -3.60161135,   2.55509369,   8.81123053,  -4.42646301,
#              -2.47168872,   4.25681986,   2.16274436,   2.53196378,
#              -3.3373208 ,   7.80132337,  11.7676954 ,  -0.82048762,
#              -7.04683734,   0.27242725,   9.24574021,  -6.05907153,
#               1.13620874, -12.27630081,   2.90112158,   4.50544205,
#               3.88644882,  -4.95312095,  13.20002596,  -2.60705997,
#              -9.26276644,  -2.9340469 ,   2.71989601,   0.15856045,
#             -13.05873204,  -7.00857085,  -2.43325726,  -5.32421287,
#              -5.38637837,   2.91375317,  -4.02473731,  -3.85861148,
{'selected_features': Index(['CNV_6q12    ', 'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ',
#             'CNV_13q34   ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_5q', 'CNV_5p',
#             'CNV_3p25.3  ',
#             ...
#             'CNV_19q13.2 ', 'CNV_7q21.2  ', 'CNV_1q21.2  ', 'CNV_3p12.1  ',
#             'CNV_3p11.1  ', 'CNV_17p11.2 ', 'CNV_13q14.2 ', 'CNV_2q22.1  ',
#             'CNV_4p', 'CNV_4q'],
#            dtype='object', length=102),
#      'coefficients': array([  7.25059918, -28.00054635,   6.35828508,  20.41950036,
#               0.16400567, -51.48533987, -54.08938866, -12.76489496,
#               0.37668758,   5.10702416, -28.07623647,  95.80628726,
#             -50.68395463,  51.62705928, -46.63806125,  41.07618584,
#             -44.1908935 ,   3.14547696,  25.86501348,   2.9597102 ,
#              22.7789387 , -30.39114388,  32.10999768, -30.9913459 ,
#              32.40904967,  58.53754339,  51.89716428,  61.11699833,
#               4.76477684,  28.36528939,  -4.92569048, -15.83376361,
#              10.17538561,  40.22787522,   1.5426816 ,  -3.14604328,
#              -1.88676676, -48.95264155,  31.76145914,  -1.22783774,
#              18.27819502, -33.08679854, -35.03893029,  58.30814503,
#              47.56363273, -20.15261969,  38.68396146,  35.95564664,
#               5.24999807,  -3.30297017, -50.72289664,  36.64265465,
#             -14.70497689, -11.80863785, -24.06687732,  65.17658292,
#              20.21445674,  57.18008856, -49.34969848, -16.5468002 ,
#              48.53752366,  22.61177921, -23.24086582, -41.66274401,
#             -25.12220405,  -7.66317891, -67.44002199,  37.73197897,
#              35.68484946, -30.31502736,  51.31354563,   6.20126408,
#             -50.40457241, -42.7551096 ,  66.80234347, -17.21278836,
#              49.95246617,   6.63277301,  37.32851209,  -2.22238255,
#             -28.93348004,   4.17206973,  22.12337677, -12.71192056,
#             -32.01250288, -13.40004582,  14.0658417 ,  38.09420866,
#              30.05928045,   3.42549716, -46.51001896,  -2.09582653,
#              36.45201402,  -9.06870583, -16.2334842 ,  43.80726778,
#               5.35660138,   4.87494891,   0.64707061,  -0.26079253,
#              -8.31705185,  -4.11194468])}}, {'lasso_model_DES': {'selected_features': Index(['CNV_5q', 'CNV_11q13.3 ', 'CNV_17q11.2 ', 'CNV_9p21.3  ', 'CNV_7p',
#             'CNV_3p12.1  '],
#            dtype='object'),
#      'coefficients': array([-16.26324891,  -0.85981544, -16.89174909,  24.45329598,
#              -2.14860077, -12.38959922])},
#     'lasso_model_FMO5': {'selected_features': Index(['CNV_6q12    ', 'CNV_21q22.3 ', 'CNV_12q24.32', 'CNV_19p',
#             'CNV_13q12.11', 'CNV_9p13.3  ', 'CNV_20p', 'CNV_19q13.33',
#             'CNV_7q36.1  ', 'CNV_15q', 'CNV_3p12.1  '],
#            dtype='object'),
#      'coefficients': array([  4.22472712,  16.54552838,  -5.18112978,  -8.74820275,
#              -9.82606932,  -5.48759425,  -7.00192853,  -7.67272384,
#              13.83370492,   4.01703328, -15.91039403])},
#     'lasso_model_HMCES': {'selected_features': Index(['CNV_6q12    ', 'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ',
#             'CNV_13q34   ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_5q', 'CNV_5p',
#             'CNV_3p25.3  ', 'CNV_2p16.1  ', 'CNV_10p15.3 ', 'CNV_21q',
#             'CNV_12q15   ', 'CNV_11p15.5 ', 'CNV_6q26    ', 'CNV_13q',
#             'CNV_17q25.3 ', 'CNV_22q11.21', 'CNV_5p12    ', 'CNV_14q11.2 ',
#             'CNV_11q25   ', 'CNV_9q21.11 ', 'CNV_7p11.2  ', 'CNV_9q',
#             'CNV_12q24.32', 'CNV_10p', 'CNV_16p13.3 ', 'CNV_9p24.1  ',
#             'CNV_8p23.2  ', 'CNV_3q', 'CNV_3p', 'CNV_9p23    ', 'CNV_1p13.2  ',
#             'CNV_8q24.21 ', 'CNV_12p13.33', 'CNV_Xp11.3  ', 'CNV_3q26.33 ',
#             'CNV_1p34.2  ', 'CNV_19p', 'CNV_5q31.1  ', 'CNV_11p', 'CNV_8p',
#             'CNV_8q', 'CNV_11q13.3 ', 'CNV_19p13.3 ', 'CNV_19q12   ',
#             'CNV_5q11.2  ', 'CNV_10q23.31', 'CNV_6p25.3  ', 'CNV_16q23.1 ',
#             'CNV_4q35.2  ', 'CNV_4p15.31 ', 'CNV_20q', 'CNV_2q31.2  ',
#             'CNV_13q12.11', 'CNV_Xq22.3  ', 'CNV_15q12   ', 'CNV_4q12    ',
#             'CNV_9p', 'CNV_16q', 'CNV_22q', 'CNV_1q', 'CNV_Xq28    ',
#             'CNV_9p13.3  ', 'CNV_21q21.1 ', 'CNV_17q11.2 ', 'CNV_9p21.3  ',
#             'CNV_14q13.3 ', 'CNV_17p', 'CNV_20q11.21', 'CNV_18p', 'CNV_18q',
#             'CNV_11q22.1 ', 'CNV_Xp21.1  ', 'CNV_20p', 'CNV_14q', 'CNV_15q26.3 ',
#             'CNV_7q', 'CNV_7p', 'CNV_17q25.1 ', 'CNV_4q32.3  ', 'CNV_1p36.32 ',
#             'CNV_18p11.32', 'CNV_18q23   ', 'CNV_15q', 'CNV_19q13.2 ',
#             'CNV_1q21.2  ', 'CNV_3p12.1  ', 'CNV_3p11.1  ', 'CNV_13q14.2 ',
#             'CNV_2q22.1  ', 'CNV_4p', 'CNV_4q'],
#            dtype='object'),
#      'coefficients': array([ 179.71546506,  -18.172138  ,   33.86955288,  303.10032697,
#             -108.64220715,   -1.47665355,  -14.3898933 , -161.72217695,
#              -33.46380418,  -41.44080734,   64.03969398,   -3.394584  ,
#               22.79560562, -101.43310537,  108.02683437,  -26.36557709,
#               32.742632  , -117.74427614,   -3.90246011,  -20.10828206,
#              -61.02137663,  -43.4097408 ,   54.54361307,  -47.82457038,
#               46.98694642,   29.07177626,  -59.02284755,   19.54403712,
#              -16.21650095,   37.26535309,   37.65685889,   19.08496103,
#              -13.92258127, -125.44697798,   64.01264201,    1.81042605,
#               52.7147702 ,  -25.94103215,   26.85694881,   25.90997369,
#               -5.2722683 ,   22.26407436,    9.25764875,   49.22213933,
#               29.02862809,  -18.28262089,  -11.23939786,  -24.428513  ,
#              -58.90918014,  -35.73172716,  -32.6740983 ,   -9.91033287,
#               -0.45894975,    0.45338453,  -40.99997427,  -14.24984837,
#               12.81181944,   -9.49617232,  -13.60144788,   22.09690565,
#              -19.50561274,    7.4849257 ,   60.93986833,  -31.33974834,
#               30.59098995,  -20.2395885 ,    2.72049744,  -22.3020626 ,
#              -17.34490639,  -20.15650722,   44.10565416,   23.47176919,
#               13.82935326,  -55.41086081,   24.549293  ,   -9.41029695,
#               10.47649115,    0.73248419,    0.38590244,    7.93876857,
#              -15.60033085,  -28.78438138,    5.53430334,   -4.2722661 ,
#               -5.38338929,  -10.59003066,   17.49481168,    0.60223053,
#                0.98141754,    4.17076729,   -4.48814218,   -3.85084003,
#               -6.63569132,   -0.32267839])},
#     'lasso_model_NEXN': {'selected_features': Index(['CNV_21q22.3 ', 'CNV_2p16.1  ', 'CNV_6q26    ', 'CNV_7p11.2  ',
#             'CNV_12q24.32', 'CNV_9p23    ', 'CNV_1p13.2  ', 'CNV_5q31.1  ',
#             'CNV_11q13.3 ', 'CNV_4q35.2  ', 'CNV_20q', 'CNV_9p', 'CNV_1q',
#             'CNV_21q21.1 ', 'CNV_9p21.3  ', 'CNV_7q36.1  ', 'CNV_8p11.23 '],
#            dtype='object'),
#      'coefficients': array([  6.12374665,   0.69980028,  -2.84907993, -31.62825366,
#              -3.81549969,  20.49711556,  -5.4314434 ,  14.52831452,
#              -7.95326853,  15.16921239,  -0.34760359,   0.10449384,
#               1.68149962,   8.60338629,   3.5298375 ,   1.48508603,
#              -1.05132399])},
#     'lasso_model_SLC7A5': {'selected_features': Index(['CNV_6q12    ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_2p16.1  ',
#             'CNV_10p15.3 ', 'CNV_21q', 'CNV_12q15   ', 'CNV_11p15.5 ',
#             'CNV_6q26    ', 'CNV_22q11.21', 'CNV_9q21.11 ', 'CNV_7p11.2  ',
#             'CNV_9q', 'CNV_12q24.32', 'CNV_7q11.22 ', 'CNV_9p24.1  ', 'CNV_3q',
#             'CNV_9p23    ', 'CNV_1p13.2  ', 'CNV_12p13.33', 'CNV_Xp11.3  ',
#             'CNV_8p', 'CNV_8q', 'CNV_19p13.3 ', 'CNV_6p25.3  ', 'CNV_Xq22.3  ',
#             'CNV_15q12   ', 'CNV_21q21.1 ', 'CNV_17q11.2 ', 'CNV_9p21.3  ',
#             'CNV_17p', 'CNV_11q22.1 ', 'CNV_20p', 'CNV_19q13.33', 'CNV_8p11.23 ',
#             'CNV_3p12.1  '],
#            dtype='object'),
#      'coefficients': array([ 1.88734811e+02, -3.83049790e+02, -2.64476764e+02, -1.36561692e+02,
#              6.31202524e+02, -3.13817819e+01,  1.68419506e+02, -3.66177900e+02,
#              4.59199127e-03,  1.85199121e+01,  1.23913575e+02, -1.09817701e+02,
#              9.90669408e-01,  3.15988719e+01,  4.84821644e+01,  5.11469805e+01,
#             -3.66771914e+01,  2.99530555e+01,  4.47660186e+01, -1.52787818e+01,
#             -2.48272771e+00,  5.03945840e+01,  1.02789904e+01,  2.13501901e+01,
#             -3.46979291e+01,  1.00098588e+01, -1.79830728e+01, -3.48556559e+01,
#              2.63192160e+01,  1.35764015e-01,  8.14272494e+01,  1.01452515e+01,
#              4.62011726e+01,  4.37856007e+01,  9.56307261e+00,  5.85825249e-03])}})}}

# %%
import pickle
file_path = 'results.pickle'

# Save the dictionary to a file using pickle
with open(file_path, 'wb') as file:
    pickle.dump(final, file)

# %%
import pickle

with open('results.pickle', 'rb') as pickle_file:
    loaded_dict = pickle.load(pickle_file)
    loaded_dict

# %%
loaded_dict
# Out:
# {'kirc': {('results_ridge',
#    'results_lasso'): ({'ridge_model_FBXO22': {('r2',
#       'mse'): [0.5278038541744479, 12108.118331040767]},
#     'ridge_model_AURKC': {('r2', 'mse'): [0.3081628865439239,
#       60.31244577978992]},
#     'ridge_model_AKAP7': {('r2', 'mse'): [0.3853871062078382,
#       3434.1929408189967]},
#     'ridge_model_CCDC158': {('r2', 'mse'): [0.37601873648677553,
#       338.5599156077676]},
#     'ridge_model_ZBTB39': {('r2', 'mse'): [0.49515469345104546,
#       146.0014927566762]}}, {'lasso_model_FBXO22': {('r2',
#       'mse'): [0.2925143068506658, 18141.44517252217]},
#     'lasso_model_AURKC': {('r2', 'mse'): [0.0, 87.17723378339558]},
#     'lasso_model_AKAP7': {('r2', 'mse'): [0.10471155613310323,
#       5002.487394877579]},
#     'lasso_model_CCDC158': {('r2', 'mse'): [0.0, 542.5802590634876]},
#     'lasso_model_ZBTB39': {('r2', 'mse'): [0.0, 289.2004557885665]}}),
#   ('models_ridge',
#    'models_lasso'): ({'ridge_model_FBXO22': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_AURKC': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_AKAP7': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_CCDC158': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_ZBTB39': Ridge(alpha=22.570197196339215, max_iter=10000)}, {'lasso_model_FBXO22': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_AURKC': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_AKAP7': Lasso(alpha=17.07352647470692, max_iter=10000),
#     'lasso_model_CCDC158': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_ZBTB39': Lasso(alpha=22.570197196339215, max_iter=10000)}),
#   ('selected_features_ridge',
#    'selected_features_lasso'): ({'ridge_model_FBXO22': {'selected_features': Index(['CNV_Xq11.2 ', 'CNV_17q24.3', 'CNV_7q36.3 ', 'CNV_3p21.32 ',
#             'CNV_14q31.1 ', 'CNV_3q26.32', 'CNV_8p23.2  ', 'CNV_3p', 'CNV_1q43    ',
#             'CNV_Xq23    ', 'CNV_4q34.3  ', 'CNV_8q24.22', 'CNV_1q24.1 ',
#             'CNV_2q37.3  ', 'CNV_9p21.3  ', 'CNV_13q13.3 ', 'CNV_6q26    ',
#             'CNV_Xp22.2 ', 'CNV_1q32.1 ', 'CNV_3p25.3  ', 'CNV_5q35.1 ',
#             'CNV_1p36.23 ', 'CNV_1p31.1  ', 'CNV_10p14  ', 'CNV_4q32.1 ',
#             'CNV_10q23.31', 'CNV_9p23    ', 'CNV_3p12.2  ', 'CNV_3q11.2  ',
#             'CNV_Xp11.4 '],
#            dtype='object'),
#      'coefficients': array([-10.04726338,  -9.57408522,   4.48148865,  13.87896796,
#             -21.82834301,  -5.998013  , -27.24660355,  13.22879329,
#              23.07711639,   0.7876628 ,  12.85527324,  -8.56263304,
#              -3.33526545, -24.43387249,  13.83867226,   2.398683  ,
#               6.68981455,  10.35729615,  27.65647534,  19.15543573,
#              20.8821128 , -25.44797144, -23.98008691, -13.16533432,
#              12.74485211,  -4.0479201 ,  -8.79776988,  -1.21138707,
#              16.84799274,  10.86188034])},
#     'ridge_model_AURKC': {'selected_features': Index(['CNV_Xq11.2 ', 'CNV_17q24.3', 'CNV_7q36.3 ', 'CNV_3p21.32 ',
#             'CNV_14q31.1 ', 'CNV_3q26.32', 'CNV_8p23.2  ', 'CNV_3p', 'CNV_1q43    ',
#             'CNV_Xq23    ', 'CNV_4q34.3  ', 'CNV_8q24.22', 'CNV_1q24.1 ',
#             'CNV_2q37.3  ', 'CNV_9p21.3  ', 'CNV_13q13.3 ', 'CNV_6q26    ',
#             'CNV_Xp22.2 ', 'CNV_1q32.1 ', 'CNV_3p25.3  ', 'CNV_5q35.1 ',
#             'CNV_1p36.23 ', 'CNV_1p31.1  ', 'CNV_10p14  ', 'CNV_4q32.1 ',
#             'CNV_10q23.31', 'CNV_9p23    ', 'CNV_3p12.2  ', 'CNV_3q11.2  ',
#             'CNV_Xp11.4 '],
#            dtype='object'),
#      'coefficients': array([ 1.38995624, -1.39288107, -0.08474369,  0.11127444,  0.4170404 ,
#              0.31753904,  0.48757684,  0.33062761,  0.44718426, -0.45469539,
#             -0.14820677, -0.24109386,  1.38665051,  0.5984315 , -0.91433619,
#             -0.13067437,  0.8323122 ,  0.59901968, -0.45757309,  0.47568651,
#              0.61961268, -0.63093318, -0.19850115,  1.87905776,  0.2836955 ,
#             -0.88556603,  0.13110266,  0.36297752, -0.15737209,  0.68244125])},
#     'ridge_model_AKAP7': {'selected_features': Index(['CNV_Xq11.2 ', 'CNV_17q24.3', 'CNV_7q36.3 ', 'CNV_3p21.32 ',
#             'CNV_14q31.1 ', 'CNV_3q26.32', 'CNV_8p23.2  ', 'CNV_3p', 'CNV_1q43    ',
#             'CNV_Xq23    ', 'CNV_4q34.3  ', 'CNV_8q24.22', 'CNV_1q24.1 ',
#             'CNV_2q37.3  ', 'CNV_9p21.3  ', 'CNV_13q13.3 ', 'CNV_6q26    ',
#             'CNV_Xp22.2 ', 'CNV_1q32.1 ', 'CNV_3p25.3  ', 'CNV_5q35.1 ',
#             'CNV_1p36.23 ', 'CNV_1p31.1  ', 'CNV_10p14  ', 'CNV_4q32.1 ',
#             'CNV_10q23.31', 'CNV_9p23    ', 'CNV_3p12.2  ', 'CNV_3q11.2  ',
#             'CNV_Xp11.4 '],
#            dtype='object'),
#      'coefficients': array([  4.31415006,   4.58698114,   2.93885209,  -2.20681184,
#             -13.81217036,   0.94808865,  -3.58673302, -12.80066827,
#               1.95814553,  -1.4970666 ,  -1.94294744,   0.46314476,
#              -9.17218707,   0.95252741,   6.78076122,  -1.526451  ,
#              17.11813387,  -0.53531335,  -1.62288468,  -0.36640124,
#              -1.58096302,  -9.60942071,   3.54398197,  12.61675987,
#              -8.58139798,  -0.91942953,   6.07623266,   1.00886627,
#              -3.03635201,  -0.84430729])},
#     'ridge_model_CCDC158': {'selected_features': Index(['CNV_Xq11.2 ', 'CNV_17q24.3', 'CNV_7q36.3 ', 'CNV_3p21.32 ',
#             'CNV_14q31.1 ', 'CNV_3q26.32', 'CNV_8p23.2  ', 'CNV_3p', 'CNV_1q43    ',
#             'CNV_Xq23    ', 'CNV_4q34.3  ', 'CNV_8q24.22', 'CNV_1q24.1 ',
#             'CNV_2q37.3  ', 'CNV_9p21.3  ', 'CNV_13q13.3 ', 'CNV_6q26    ',
#             'CNV_Xp22.2 ', 'CNV_1q32.1 ', 'CNV_3p25.3  ', 'CNV_5q35.1 ',
#             'CNV_1p36.23 ', 'CNV_1p31.1  ', 'CNV_10p14  ', 'CNV_4q32.1 ',
#             'CNV_10q23.31', 'CNV_9p23    ', 'CNV_3p12.2  ', 'CNV_3q11.2  ',
#             'CNV_Xp11.4 '],
#            dtype='object'),
#      'coefficients': array([ 0.97424388, -0.96879351, -1.09806559,  0.05748049, -4.06348914,
#             -0.84560046,  2.6773558 , -2.12591919, -5.1790401 , -0.03313131,
#              1.8212586 , -0.8725822 , -0.69417318,  0.60498497,  2.73698908,
#             -4.20266377,  0.6429262 , -0.23842296,  3.7031513 , -0.09444846,
#              0.9842568 ,  0.47887999,  0.76825619,  1.40612812,  1.10421533,
#             -0.53563773,  3.49276563,  2.28797945, -1.71367459, -0.15650283])},
#     'ridge_model_ZBTB39': {'selected_features': Index(['CNV_Xq11.2 ', 'CNV_17q24.3', 'CNV_7q36.3 ', 'CNV_3p21.32 ',
#             'CNV_14q31.1 ', 'CNV_3q26.32', 'CNV_8p23.2  ', 'CNV_3p', 'CNV_1q43    ',
#             'CNV_Xq23    ', 'CNV_4q34.3  ', 'CNV_8q24.22', 'CNV_1q24.1 ',
#             'CNV_2q37.3  ', 'CNV_9p21.3  ', 'CNV_13q13.3 ', 'CNV_6q26    ',
#             'CNV_Xp22.2 ', 'CNV_1q32.1 ', 'CNV_3p25.3  ', 'CNV_5q35.1 ',
#             'CNV_1p36.23 ', 'CNV_1p31.1  ', 'CNV_10p14  ', 'CNV_4q32.1 ',
#             'CNV_10q23.31', 'CNV_9p23    ', 'CNV_3p12.2  ', 'CNV_3q11.2  ',
#             'CNV_Xp11.4 '],
#            dtype='object'),
#      'coefficients': array([ 0.52712834, -2.31685254, -1.72339805,  0.33801023,  3.08357004,
#              1.5495341 ,  3.84642372, -2.17327306,  1.15074528, -0.57613124,
#              0.6529426 , -2.30404673, -2.81228437,  0.87099041,  1.64575265,
#              1.49961992, -0.05188852,  1.60351338, -0.56467915, -0.50729587,
#             -1.43201817,  1.19244148,  1.13540238, -1.80553257, -2.18124332,
#              1.62378686, -0.11450102, -1.55911933, -0.34745654,  1.76585826])}}, {'lasso_model_FBXO22': {'selected_features': Index(['CNV_14q31.1 ', 'CNV_8p23.2  ', 'CNV_1q43    ', 'CNV_1q32.1 ',
#             'CNV_3p25.3  ', 'CNV_5q35.1 ', 'CNV_1p36.23 ', 'CNV_1p31.1  '],
#            dtype='object'),
#      'coefficients': array([-11.08483017, -17.79524206,  11.03127461,  21.92813829,
#              22.64658349,   1.34783759,  -6.93521083, -17.83173166])},
#     'lasso_model_AURKC': {'selected_features': Index([], dtype='object'),
#      'coefficients': array([], dtype=float64)},
#     'lasso_model_AKAP7': {'selected_features': Index(['CNV_3p', 'CNV_6q26    '], dtype='object'),
#      'coefficients': array([-5.66953075,  8.51073461])},
#     'lasso_model_CCDC158': {'selected_features': Index([], dtype='object'),
#      'coefficients': array([], dtype=float64)},
#     'lasso_model_ZBTB39': {'selected_features': Index([], dtype='object'),
#      'coefficients': array([], dtype=float64)}})},
#  'lusc': {('results_ridge',
#    'results_lasso'): ({'ridge_model_DES': {('r2', 'mse'): [0.9999992093904378,
#       0.006586707294205562]},
#     'ridge_model_FMO5': {('r2', 'mse'): [0.9248989791381171,
#       307.8646042841314]},
#     'ridge_model_HMCES': {('r2', 'mse'): [0.9654634919721381,
#       10174.446298554061]},
#     'ridge_model_NEXN': {('r2', 'mse'): [0.9988059709837754,
#       4.014956796828832]},
#     'ridge_model_SLC7A5': {('r2', 'mse'): [0.9398826561063115,
#       77847.08303096736]}}, {'lasso_model_DES': {('r2',
#       'mse'): [0.5954810209272261, 3370.1187511129515]},
#     'lasso_model_FMO5': {('r2', 'mse'): [0.9135209258064937,
#       354.50711122030367]},
#     'lasso_model_HMCES': {('r2', 'mse'): [0.9999999918551148,
#       0.0023994810562466685]},
#     'lasso_model_NEXN': {('r2', 'mse'): [0.9999974407625158,
#       0.008605509407394712]},
#     'lasso_model_SLC7A5': {('r2', 'mse'): [0.9999999268929504,
#       0.094667698173142]}}),
#   ('models_ridge',
#    'models_lasso'): ({'ridge_model_DES': Ridge(alpha=0.01, max_iter=10000),
#     'ridge_model_FMO5': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_HMCES': Ridge(alpha=22.570197196339215, max_iter=10000),
#     'ridge_model_NEXN': Ridge(alpha=1.384886371393873, max_iter=10000),
#     'ridge_model_SLC7A5': Ridge(alpha=22.570197196339215, max_iter=10000)}, {'lasso_model_DES': Lasso(alpha=22.570197196339215, max_iter=10000),
#     'lasso_model_FMO5': Lasso(alpha=6.7341506577508286, max_iter=10000),
#     'lasso_model_HMCES': Lasso(alpha=0.01, max_iter=10000),
#     'lasso_model_NEXN': Lasso(alpha=0.025353644939701114, max_iter=10000),
#     'lasso_model_SLC7A5': Lasso(alpha=0.0774263682681127, max_iter=10000)}),
#   ('selected_features_ridge',
#    'selected_features_lasso'): ({'ridge_model_DES': {'selected_features': Index(['CNV_6q12    ', 'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ',
#             'CNV_13q34   ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_5q', 'CNV_5p',
#             'CNV_3p25.3  ',
#             ...
#             'CNV_19q13.2 ', 'CNV_7q21.2  ', 'CNV_1q21.2  ', 'CNV_3p12.1  ',
#             'CNV_3p11.1  ', 'CNV_17p11.2 ', 'CNV_13q14.2 ', 'CNV_2q22.1  ',
#             'CNV_4p', 'CNV_4q'],
#            dtype='object', length=102),
#      'coefficients': array([ 31.48060036,  -1.20979486,  -7.84925279,  -7.69775213,
#               8.86496014,   4.0498432 ,  -1.20291803, -12.11557966,
#              -8.81219931, -10.49312872,  -9.8984265 ,  -9.89230922,
#               8.48355062,   0.04341117,   1.9480441 , -11.48609287,
#               2.76150947,   7.24366523,   8.56454878,  -2.08132097,
#               1.32148698,  -0.80179343,   3.49382142,   1.35962967,
#              -3.60161135,   2.55509369,   8.81123053,  -4.42646301,
#              -2.47168872,   4.25681986,   2.16274436,   2.53196378,
#              -3.3373208 ,   7.80132337,  11.7676954 ,  -0.82048762,
#              -7.04683734,   0.27242725,   9.24574021,  -6.05907153,
#               1.13620874, -12.27630081,   2.90112158,   4.50544205,
#               3.88644882,  -4.95312095,  13.20002596,  -2.60705997,
#              -9.26276644,  -2.9340469 ,   2.71989601,   0.15856045,
#             -13.05873204,  -7.00857085,  -2.43325726,  -5.32421287,
#              -5.38637837,   2.91375317,  -4.02473731,  -3.85861148,
#               1.52822194,   9.00005139,  -3.26514133,   2.71489012,
#               6.80057178,  -2.09271196,  -2.22431868,  -8.36924176,
#               9.84616424,  -2.12006622,   4.80854771,   2.1108933 ,
#              -2.34661564,  -6.28768832,  -0.54256265,  -5.84173396,
#              -7.16297172,  -2.42214683,  -3.88697917,   7.0002292 ,
#              -1.80794113,  -2.24319658,  11.01341594,  -8.10365291,
#               6.97580566,   7.08478939,  -5.20671752,   4.59503493,
#               1.51059984,  -8.64436723,   3.88523808,  -5.3893685 ,
#               1.49251669,   6.96210012,  -7.1939001 , -13.02892326,
#              -2.47976833,   1.12939211,  -6.08878772, -15.94407827,
#              -7.86685797,  -9.01295171])},
#     'ridge_model_FMO5': {'selected_features': Index(['CNV_6q12    ', 'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ',
#             'CNV_13q34   ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_5q', 'CNV_5p',
#             'CNV_3p25.3  ',
#             ...
#             'CNV_19q13.2 ', 'CNV_7q21.2  ', 'CNV_1q21.2  ', 'CNV_3p12.1  ',
#             'CNV_3p11.1  ', 'CNV_17p11.2 ', 'CNV_13q14.2 ', 'CNV_2q22.1  ',
#             'CNV_4p', 'CNV_4q'],
#            dtype='object', length=102),
#      'coefficients': array
{'selected_features': Index(['CNV_6q12    ', 'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ',
#             'CNV_13q34   ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_5q', 'CNV_5p',
#             'CNV_3p25.3  ',
#             ...
#             'CNV_19q13.2 ', 'CNV_7q21.2  ', 'CNV_1q21.2  ', 'CNV_3p12.1  ',
#             'CNV_3p11.1  ', 'CNV_17p11.2 ', 'CNV_13q14.2 ', 'CNV_2q22.1  ',
#             'CNV_4p', 'CNV_4q'],
#            dtype='object', length=102),
#      'coefficients': array([  7.25059918, -28.00054635,   6.35828508,  20.41950036,
#               0.16400567, -51.48533987, -54.08938866, -12.76489496,
#               0.37668758,   5.10702416, -28.07623647,  95.80628726,
#             -50.68395463,  51.62705928, -46.63806125,  41.07618584,
#             -44.1908935 ,   3.14547696,  25.86501348,   2.9597102 ,
#              22.7789387 , -30.39114388,  32.10999768, -30.9913459 ,
#              32.40904967,  58.53754339,  51.89716428,  61.11699833,
#               4.76477684,  28.36528939,  -4.92569048, -15.83376361,
#              10.17538561,  40.22787522,   1.5426816 ,  -3.14604328,
#              -1.88676676, -48.95264155,  31.76145914,  -1.22783774,
#              18.27819502, -33.08679854, -35.03893029,  58.30814503,
#              47.56363273, -20.15261969,  38.68396146,  35.95564664,
#               5.24999807,  -3.30297017, -50.72289664,  36.64265465,
#             -14.70497689, -11.80863785, -24.06687732,  65.17658292,
#              20.21445674,  57.18008856, -49.34969848, -16.5468002 ,
#              48.53752366,  22.61177921, -23.24086582, -41.66274401,
#             -25.12220405,  -7.66317891, -67.44002199,  37.73197897,
#              35.68484946, -30.31502736,  51.31354563,   6.20126408,
#             -50.40457241, -42.7551096 ,  66.80234347, -17.21278836,
#              49.95246617,   6.63277301,  37.32851209,  -2.22238255,
#             -28.93348004,   4.17206973,  22.12337677, -12.71192056,
#             -32.01250288, -13.40004582,  14.0658417 ,  38.09420866,
#              30.05928045,   3.42549716, -46.51001896,  -2.09582653,
#              36.45201402,  -9.06870583, -16.2334842 ,  43.80726778,
#               5.35660138,   4.87494891,   0.64707061,  -0.26079253,
#              -8.31705185,  -4.11194468])}}, {'lasso_model_DES': {'selected_features': Index(['CNV_5q', 'CNV_11q13.3 ', 'CNV_17q11.2 ', 'CNV_9p21.3  ', 'CNV_7p',
#             'CNV_3p12.1  '],
#            dtype='object'),
#      'coefficients': array([-16.26324891,  -0.85981544, -16.89174909,  24.45329598,
#              -2.14860077, -12.38959922])},
#     'lasso_model_FMO5': {'selected_features': Index(['CNV_6q12    ', 'CNV_21q22.3 ', 'CNV_12q24.32', 'CNV_19p',
#             'CNV_13q12.11', 'CNV_9p13.3  ', 'CNV_20p', 'CNV_19q13.33',
#             'CNV_7q36.1  ', 'CNV_15q', 'CNV_3p12.1  '],
#            dtype='object'),
#      'coefficients': array([  4.22472712,  16.54552838,  -5.18112978,  -8.74820275,
#              -9.82606932,  -5.48759425,  -7.00192853,  -7.67272384,
#              13.83370492,   4.01703328, -15.91039403])},
#     'lasso_model_HMCES': {'selected_features': Index(['CNV_6q12    ', 'CNV_18q11.2 ', 'CNV_12p', 'CNV_4q22.1  ',
#             'CNV_13q34   ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_5q', 'CNV_5p',
#             'CNV_3p25.3  ', 'CNV_2p16.1  ', 'CNV_10p15.3 ', 'CNV_21q',
#             'CNV_12q15   ', 'CNV_11p15.5 ', 'CNV_6q26    ', 'CNV_13q',
#             'CNV_17q25.3 ', 'CNV_22q11.21', 'CNV_5p12    ', 'CNV_14q11.2 ',
#             'CNV_11q25   ', 'CNV_9q21.11 ', 'CNV_7p11.2  ', 'CNV_9q',
#             'CNV_12q24.32', 'CNV_10p', 'CNV_16p13.3 ', 'CNV_9p24.1  ',
#             'CNV_8p23.2  ', 'CNV_3q', 'CNV_3p', 'CNV_9p23    ', 'CNV_1p13.2  ',
#             'CNV_8q24.21 ', 'CNV_12p13.33', 'CNV_Xp11.3  ', 'CNV_3q26.33 ',
#             'CNV_1p34.2  ', 'CNV_19p', 'CNV_5q31.1  ', 'CNV_11p', 'CNV_8p',
#             'CNV_8q', 'CNV_11q13.3 ', 'CNV_19p13.3 ', 'CNV_19q12   ',
#             'CNV_5q11.2  ', 'CNV_10q23.31', 'CNV_6p25.3  ', 'CNV_16q23.1 ',
#             'CNV_4q35.2  ', 'CNV_4p15.31 ', 'CNV_20q', 'CNV_2q31.2  ',
#             'CNV_13q12.11', 'CNV_Xq22.3  ', 'CNV_15q12   ', 'CNV_4q12    ',
#             'CNV_9p', 'CNV_16q', 'CNV_22q', 'CNV_1q', 'CNV_Xq28    ',
#             'CNV_9p13.3  ', 'CNV_21q21.1 ', 'CNV_17q11.2 ', 'CNV_9p21.3  ',
#             'CNV_14q13.3 ', 'CNV_17p', 'CNV_20q11.21', 'CNV_18p', 'CNV_18q',
#             'CNV_11q22.1 ', 'CNV_Xp21.1  ', 'CNV_20p', 'CNV_14q', 'CNV_15q26.3 ',
#             'CNV_7q', 'CNV_7p', 'CNV_17q25.1 ', 'CNV_4q32.3  ', 'CNV_1p36.32 ',
#             'CNV_18p11.32', 'CNV_18q23   ', 'CNV_15q', 'CNV_19q13.2 ',
#             'CNV_1q21.2  ', 'CNV_3p12.1  ', 'CNV_3p11.1  ', 'CNV_13q14.2 ',
#             'CNV_2q22.1  ', 'CNV_4p', 'CNV_4q'],
#            dtype='object'),
#      'coefficients': array([ 179.71546506,  -18.172138  ,   33.86955288,  303.10032697,
#             -108.64220715,   -1.47665355,  -14.3898933 , -161.72217695,
#              -33.46380418,  -41.44080734,   64.03969398,   -3.394584  ,
#               22.79560562, -101.43310537,  108.02683437,  -26.36557709,
#               32.742632  , -117.74427614,   -3.90246011,  -20.10828206,
#              -61.02137663,  -43.4097408 ,   54.54361307,  -47.82457038,
#               46.98694642,   29.07177626,  -59.02284755,   19.54403712,
#              -16.21650095,   37.26535309,   37.65685889,   19.08496103,
#              -13.92258127, -125.44697798,   64.01264201,    1.81042605,
#               52.7147702 ,  -25.94103215,   26.85694881,   25.90997369,
#               -5.2722683 ,   22.26407436,    9.25764875,   49.22213933,
#               29.02862809,  -18.28262089,  -11.23939786,  -24.428513  ,
#              -58.90918014,  -35.73172716,  -32.6740983 ,   -9.91033287,
#               -0.45894975,    0.45338453,  -40.99997427,  -14.24984837,
#               12.81181944,   -9.49617232,  -13.60144788,   22.09690565,
#              -19.50561274,    7.4849257 ,   60.93986833,  -31.33974834,
#               30.59098995,  -20.2395885 ,    2.72049744,  -22.3020626 ,
#              -17.34490639,  -20.15650722,   44.10565416,   23.47176919,
#               13.82935326,  -55.41086081,   24.549293  ,   -9.41029695,
#               10.47649115,    0.73248419,    0.38590244,    7.93876857,
#              -15.60033085,  -28.78438138,    5.53430334,   -4.2722661 ,
#               -5.38338929,  -10.59003066,   17.49481168,    0.60223053,
#                0.98141754,    4.17076729,   -4.48814218,   -3.85084003,
#               -6.63569132,   -0.32267839])},
#     'lasso_model_NEXN': {'selected_features': Index(['CNV_21q22.3 ', 'CNV_2p16.1  ', 'CNV_6q26    ', 'CNV_7p11.2  ',
#             'CNV_12q24.32', 'CNV_9p23    ', 'CNV_1p13.2  ', 'CNV_5q31.1  ',
#             'CNV_11q13.3 ', 'CNV_4q35.2  ', 'CNV_20q', 'CNV_9p', 'CNV_1q',
#             'CNV_21q21.1 ', 'CNV_9p21.3  ', 'CNV_7q36.1  ', 'CNV_8p11.23 '],
#            dtype='object'),
#      'coefficients': array([  6.12374665,   0.69980028,  -2.84907993, -31.62825366,
#              -3.81549969,  20.49711556,  -5.4314434 ,  14.52831452,
#              -7.95326853,  15.16921239,  -0.34760359,   0.10449384,
#               1.68149962,   8.60338629,   3.5298375 ,   1.48508603,
#              -1.05132399])},
#     'lasso_model_SLC7A5': {'selected_features': Index(['CNV_6q12    ', 'CNV_21q22.3 ', 'CNV_2q36.2  ', 'CNV_2p16.1  ',
#             'CNV_10p15.3 ', 'CNV_21q', 'CNV_12q15   ', 'CNV_11p15.5 ',
#             'CNV_6q26    ', 'CNV_22q11.21', 'CNV_9q21.11 ', 'CNV_7p11.2  ',
#             'CNV_9q', 'CNV_12q24.32', 'CNV_7q11.22 ', 'CNV_9p24.1  ', 'CNV_3q',
#             'CNV_9p23    ', 'CNV_1p13.2  ', 'CNV_12p13.33', 'CNV_Xp11.3  ',
#             'CNV_8p', 'CNV_8q', 'CNV_19p13.3 ', 'CNV_6p25.3  ', 'CNV_Xq22.3  ',
#             'CNV_15q12   ', 'CNV_21q21.1 ', 'CNV_17q11.2 ', 'CNV_9p21.3  ',
#             'CNV_17p', 'CNV_11q22.1 ', 'CNV_20p', 'CNV_19q13.33', 'CNV_8p11.23 ',
#             'CNV_3p12.1  '],
#            dtype='object'),
#      'coefficients': array([ 1.88734811e+02, -3.83049790e+02, -2.64476764e+02, -1.36561692e+02,
#              6.31202524e+02, -3.13817819e+01,  1.68419506e+02, -3.66177900e+02,
#              4.59199127e-03,  1.85199121e+01,  1.23913575e+02, -1.09817701e+02,
#              9.90669408e-01,  3.15988719e+01,  4.84821644e+01,  5.11469805e+01,
#             -3.66771914e+01,  2.99530555e+01,  4.47660186e+01, -1.52787818e+01,
#             -2.48272771e+00,  5.03945840e+01,  1.02789904e+01,  2.13501901e+01,
#             -3.46979291e+01,  1.00098588e+01, -1.79830728e+01, -3.48556559e+01,
#              2.63192160e+01,  1.35764015e-01,  8.14272494e+01,  1.01452515e+01,
#              4.62011726e+01,  4.37856007e+01,  9.56307261e+00,  5.85825249e-03])}})}}
